# %% [markdown]
# # Anagrams (Recursive)

# %% [markdown]
# From Wikipedia (https://en.wikipedia.org/wiki/Anagram):
#
# An anagram is direct word switch or word play, the result of rearranging the letters of a word or phrase to produce a new word or phrase, using all the original letters exactly once; for example, the word anagram can be rearranged into nag-a-ram. Someone who creates anagrams may be called an "anagrammatist".[1] The original word or phrase is known as the subject of the anagram. Anagrams are often used as a form of mnemonic device as well.
#
# Any word or phrase that exactly reproduces the letters in another order is an anagram. However, the goal of serious or skilled anagrammatists is to produce anagrams that in some way reflect or comment on the subject.

# %% [markdown]
# Write a recursive program that will output every anagram of an input string. It is not recomended that your test word be longer than 6 characters.

# %%
def anagram(the_string):
    '''
        Recursive function to print to the screen every 
        anagram of the input string. Input parameters:
           the_string - the string to make anagrams from
    '''
    
    # Base case for recursion
    if len(the_string) == 1:
        return the_string
    
    # List we will be storing answers in
    answer = []
    
    # For each letter in the_string, take a 
    # letter out and recursively call again
    for i in range(len(the_string)):
        new_string = the_string[:i] + the_string[i+1:]
        letter = the_string[i]
        
        # Recursive call
        for i in anagram(new_string):
            answer.append(letter + i)
        
    # Get rid of duplicates
    answer = list(set(answer))
    
    return answer

# %%
mylist = anagram('testing')
print len(mylist)
print mylist
# Out:
# 2520
# ['ttensig', 'stentgi', 'nsiettg', 'igttnse', 'tsniget', 'tgietsn', 'inttgse', 'stginet', 'gtintse', 'isgentt', 'netsitg', 'tsgtnei', 'tsiegtn', 'sneittg', 'getinst', 'tgseitn', 'stegitn', 'ietstng', 'iettsng', 'tigtens', 'tetgsni', 'stntgie', 'inttegs', 'snegitt', 'gsitent', 'nsgtiet', 'iegstnt', 'ttensgi', 'seitngt', 'itntgse', 'ntitseg', 'tegntis', 'ntetsgi', 'tiestng', 'tiengts', 'nigttes', 'intestg', 'itetngs', 'sttigne', 'tsetngi', 'esttgin', 'nsgttei', 'tsgient', 'tgstine', 'tsientg', 'tnsgtie', 'sitgten', 'sntiget', 'tgienst', 'nsgeitt', 'itgsten', 'sgeitnt', 'ntetsig', 'etingst', 'ettngis', 'ntstgei', 'ngttsei', 'gsetnti', 'igesttn', 'ittesgn', 'gtsetin', 'sntgeti', 'sgiettn', 'etnsigt', 'segttin', 'iesttng', 'ittnegs', 'tgneist', 'gtetsin', 'tiensgt', 'nsgitet', 'intsegt', 'stneitg', 'ietgnts', 'tientsg', 'estting', 'gttines', 'ttegnsi', 'itgnest', 'teingst', 'etisntg', 'ntitegs', 'geisntt', 'ingsett', 'tgsntie', 'gsttnie', 'tgsteni', 'ttgsien', 'sginett', 'snttieg', 'tgeistn', 'gnsitte', 'iettngs', 'gstenti', 'nsettgi', 'tengtsi', 'einttsg', 'eisngtt', 'tneistg', 'esigntt', 'gstnite', 'gintste', 'esgtnti', 'ttiensg', 'tgstnie', 'nstetgi', 'einsgtt', 'sgetnti', 'nsgtite', 'gntitse', 'itnegts', 'esnittg', 'tnisegt', 'tiegsnt', 'sintget', 'isegntt', 'neigtts', 'igstetn', 'igentts', 'etsntgi', 'negstti', 'inesttg', 'sgintet', 'gtesint', 'igtntse', 'sigtnet', 'sgnteti', 'stnegit', 'ietstgn', 'ettinsg', 'etsgitn', 'tegsitn', 'engitts', 'snteigt', 'gnettis', 'entigts', 'gsnetit', 'sngetit', 'sgtenit', 'integst', 'gtensti', 'eisgtnt', 'ttsegni', 'sngttei', 'stigent', 'gttesin', 'entgsti', 'isgnett', 'tnisget', 'getntsi', 'ngtties', 'engttsi', 'ttngsei', 'istteng', 'tgnseti', 'titnesg', 'nstgtie', 'sgietnt', 'titsnge', 'tniesgt', 'tesignt', 'ietsgtn', 'gtisten', 'siegtnt', 'eitgtsn', 'tsteign', 'isettng', 'gtstein', 'eitgnst', 'stitgne', 'seittgn', 'ngsiett', 'itsetng', 'sgitent', 'nteigst', 'etntgis', 'isnegtt', 'sgntite', 'esittgn', 'nsttieg', 'ntteisg', 'tnsigte', 'tgtsein', 'nttegsi', 'tgsitne', 'tiegtsn', 'igstnte', 'gtntsei', 'tegtisn', 'etnistg', 'esitngt', 'iesngtt', 'tniegst', 'etsigtn', 'tetsngi', 'stgtine', 'tnesigt', 'ntgtsie', 'nesgitt', 'tignset', 'ttniges', 'sgtniet', 'itegstn', 'tgnsite', 'ngsteit', 'netsgit', 'tsgeitn', 'entstig', 'gntstei', 'nseigtt', 'ntietgs', 'ntegsit', 'egtistn', 'gitsnet', 'ntsigte', 'seinttg', 'tgtisne', 'nttsige', 'gtensit', 'tgtnsie', 'sintetg', 'ietsgnt', 'ttsneig', 'ttsgnie', 'ntsiteg', 'ttniseg', 'ngietst', 'sitgetn', 'engstti', 'ngsttie', 'igtsetn', 'teitsng', 'tesitgn', 'tsitgen', 'tgisnte', 'egstnti', 'sitengt', 'ttgnsie', 'tintesg', 'isngtte', 'teisngt', 'gtnseti', 'tstineg', 'ngettis', 'intstge', 'itgnste', 'ntiesgt', 'inetstg', 'itntges', 'tstenig', 'ngesitt', 'gtsinte', 'ntgiset', 'tgntesi', 'nteitsg', 'eisttng', 'eitntsg', 'tgnetsi', 'tsnteig', 'ntgesit', 'ntsgeti', 'tetings', 'gtiestn', 'tnsgeit', 'tnisetg', 'tigtnse', 'teigsnt', 'enitstg', 'sietgtn', 'niegstt', 'entsigt', 'tgnitse', 'entgist', 'stgitne', 'tisnteg', 'igsttne', 'tgesint', 'tgisten', 'egitnts', 'gnietts', 'tnsiget', 'entsgit', 'tnegsti', 'tienstg', 'ttesgin', 'tinstge', 'tngites', 'tesgnti', 'gentsti', 'tngesti', 'tgsneit', 'ttesign', 'ngetist', 'nstiget', 'tietngs', 'esinttg', 'tniegts', 'iegtstn', 'igttsne', 'negtsti', 'netigts', 'ntiegts', 'gtetins', 'itstneg', 'tsntegi', 'snteitg', 'setgnti', 'tsniegt', 'tgisent', 'istgtne', 'tgsinet', 'sgnttei', 'sgteitn', 'tgenits', 'tsegtni', 'sniettg', 'esigtnt', 'ittesng', 'isetgnt', 'estgnti', 'tsintge', 'ntsegti', 'getsitn', 'gisntte', 'tentgis', 'gtesnti', 'gntstie', 'gttnies', 'egttsni', 'inegtts', 'ittsneg', 'ntsiegt', 'gtsntei', 'eintgts', 'ingstet', 'sgntiet', 'tetsgni', 'gettsin', 'ngetsti', 'gstitne', 'itntsge', 'ettisgn', 'tgtensi', 'ntistge', 'tetigsn', 'gntiest', 'ngtstei', 'etgnsit', 'egstitn', 'tingest', 'tsginte', 'stinget', 'tgetisn', 'isntegt', 'itetnsg', 'testing', 'sitnegt', 'itgsnte', 'egsintt', 'nsttgie', 'gnsttie', 'egintst', 'engtsti', 'stneg ...

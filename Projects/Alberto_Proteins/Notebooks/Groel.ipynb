# %%
# %matplotlib notebook
import prody

# %%
pdb = prody.parsePDB('1sx4')

# %%
pdb = pdb.select('protein')

# %%
pdb
# Out:
# <Selection: 'protein' from 1sx4 (59080 atoms)>

# %%
prody.showProtein(pdb)
# Out:
# <img src="data:image/png;base64,...">

# %%
chain_A = pdb.select('chain A and name CA')

# %%
anm_A = prody.ANM('Chain A')

# %%
anm_A.buildHessian(chain_A)

# %%
anm_A.calcModes()

# %%
prody.writeNMD('Groel_A.nmd',anm_A[:3],chain_A)
# Out:
# 'Groel_A.nmd'

# %%
groel = pdb.select('name CA')

# %% [markdown]
# anm = prody.ANM('Groel')

# %%
anm = prody.ANM('Groel')

# %%
anm.buildHessian(groel)

# %%
anm.calcModes()

# %%
prody.writeNMD('Groel.nmd',anm[:3],groel)

# %%
anm.getEigvals()

# %%
anm.getEigvecs()

# %%
gnm_A = prody.GNM('chain A')

# %%
gnm_A.buildKirchhoff(chain_A)

# %%
gnm_A.calcModes()

# %%
prody.writeNMD('Groel_GNM_A.nmd',gnm_A[:3],chain_A)
# Out:
# 'Groel_GNM_A.nmd'
